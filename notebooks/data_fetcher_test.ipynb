# %% [markdown]
# # data_fetcher package / main.py

# %% [markdown]
# ### Ver1.

# %%
import os
from data_fetcher.config import MAIZE_INDIA_LOCATIONS, SORGHUM_KENYA_LOCATIONS
from data_fetcher.fetcher import fetch_weather_data
from data_fetcher.validator import validate_weather_data
from data_fetcher.saver import save_partitioned_parquet_s3

if __name__ == "__main__":
    # Get bucket name and base prefix from environment variables.
    S3_BUCKET_NAME = os.getenv("BRONZE_BUCKET", "gdd-raw-weather-data")
    BASE_S3_PREFIX = os.getenv("BRONZE_S3_PREFIX", "bronze")

    # Define locations to process.
    locations_to_process_config = {
        "maize": MAIZE_INDIA_LOCATIONS,
        "sorghum": SORGHUM_KENYA_LOCATIONS
    }

    print(f"Starting batch processing. Target S3 Bucket: {S3_BUCKET_NAME}, Base Prefix: {BASE_S3_PREFIX}")

    for crop_id, locations_map in locations_to_process_config.items():
        for location_id, (lat, lon) in locations_map.items():
            print(f"Processing: Crop='{crop_id}', Location='{location_id}', Coords=({lat}, {lon})")
            try:
                print(f"  1. Fetching weather data for {location_id}...")
                df_raw = fetch_weather_data(lat, lon, location_id)
                df_raw['crop_id'] = crop_id  # Add crop_id for validation and saving.

                print(f"  2. Validating weather data for {location_id}...")
                df_validated = validate_weather_data(df_raw.copy())

                print(f"  3. Saving data for {location_id} to S3...")
                save_partitioned_parquet_s3(df_validated, bucket=S3_BUCKET_NAME, base_prefix=BASE_S3_PREFIX)
                print(f"  Data for {crop_id} - {location_id} saved successfully.")
            except Exception as e:
                print(f"  ERROR processing {crop_id} - {location_id}: {e}")

    print("Batch processing finished.")
# Out:
# Starting batch processing. Target S3 Bucket: gdd-raw-weather-data, Base Prefix: bronze
# Processing: Crop='maize', Location='Belagavi', Coords=(15.85, 74.5)
#   1. Fetching weather data for Belagavi...
#   2. Validating weather data for Belagavi...
#   3. Saving data for Belagavi to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Belagavi/data_2025-05-23.parquet
#   Data for maize - Belagavi saved successfully.
# Processing: Crop='maize', Location='Chhindwara', Coords=(22.06, 78.94)
#   1. Fetching weather data for Chhindwara...
#   2. Validating weather data for Chhindwara...
#   3. Saving data for Chhindwara to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Chhindwara/data_2025-05-23.parquet
#   Data for maize - Chhindwara saved successfully.
# Processing: Crop='maize', Location='Jalgaon', Coords=(21.01, 75.56)
#   1. Fetching weather data for Jalgaon...
#   2. Validating weather data for Jalgaon...
#   3. Saving data for Jalgaon to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Jalgaon/data_2025-05-23.parquet
#   Data for maize - Jalgaon saved successfully.
# Processing: Crop='maize', Location='Perambalur', Coords=(11.23, 78.88)
#   1. Fetching weather data for Perambalur...
#   2. Validating weather data for Perambalur...
#   3. Saving data for Perambalur to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Perambalur/data_2025-05-23.parquet
#   Data for maize - Perambalur saved successfully.
# Processing: Crop='maize', Location='Katihar', Coords=(25.54, 87.58)
#   1. Fetching weather data for Katihar...
#   2. Validating weather data for Katihar...
#   3. Saving data for Katihar to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Katihar/data_2025-05-23.parquet
#   Data for maize - Katihar saved successfully.
# Processing: Crop='sorghum', Location='Kitui', Coords=(-1.38, 38.01)
#   1. Fetching weather data for Kitui...
#   2. Validating weather data for Kitui...
#   3. Saving data for Kitui to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Kitui/data_2025-05-23.parquet
#   Data for sorghum - Kitui saved successfully.
# Processing: Crop='sorghum', Location='Machakos', Coords=(-1.52, 37.27)
#   1. Fetching weather data for Machakos...
#   2. Validating weather data for Machakos...
#   3. Saving data for Machakos to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Machakos/data_2025-05-23.parquet
#   Data for sorghum - Machakos saved successfully.
# Processing: Crop='sorghum', Location='Makueni', Coords=(-2.24, 37.96)
#   1. Fetching weather data for Makueni...
#   2. Validating weather data for Makueni...
#   3. Saving data for Makueni to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Makueni/data_2025-05-23.parquet
#   Data for sorghum - Makueni saved successfully.
# Processing: Crop='sorghum', Location='Tharaka_Nithi', Coords=(-0.3, 37.93)
#   1. Fetching weather data for Tharaka_Nithi...
#   2. Validating weather data for Tharaka_Nithi...
#   3. Saving data for Tharaka_Nithi to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Tharaka_Nithi/data_2025-05-23.parquet
#   Data for sorghum - Tharaka_Nithi saved successfully.
# Processing: Crop='sorghum', Location='Siaya', Coords=(0.06, 34.29)
#   1. Fetching weather data for Siaya...
#   2. Validating weather data for Siaya...
#   3. Saving data for Siaya to S3...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Siaya/data_2025-05-23.parquet
#   Data for sorghum - Siaya saved successfully.
# Batch processing finished.

# %% [markdown]
# ### Refactored - Ver2.

# %%
from data_fetcher.config import (
    MAIZE_INDIA_LOCATIONS,
    SORGHUM_KENYA_LOCATIONS,
)  
from data_fetcher.fetcher import fetch_weather_data  
from data_fetcher.validator import validate_weather_data  
from data_fetcher.saver import save_partitioned_parquet_s3 

try:
    from universal import config as app_config
except ImportError:
    exit(
        "CRITICAL ERROR: Could not import shared configuration from 'universal.config'. Please ensure 'gdd-app' is in PYTHONPATH and 'universal/config.py' exists."
    )


if __name__ == "__main__":
    # Determine target bucket name and base prefix from shared app_config
    target_bucket_name = None
    if app_config.STORAGE_BACKEND == "minio":
        target_bucket_name = app_config.MINIO_DATA_BUCKET_NAME
    elif app_config.STORAGE_BACKEND == "s3":
        target_bucket_name = app_config.AWS_S3_DATA_BUCKET_NAME
    else:
        print(
            f"Error: Invalid STORAGE_BACKEND '{app_config.STORAGE_BACKEND}' defined in shared config."
        )
        exit(1)

    if not target_bucket_name:
        print(
            f"Error: Target bucket name could not be determined for backend '{app_config.STORAGE_BACKEND}'. Ensure it's set in shared config."
        )
        exit(1)

    base_s3_prefix = app_config.BRONZE_PREFIX

    # Define locations to process.
    locations_to_process_config = {
        "maize": MAIZE_INDIA_LOCATIONS,
        "sorghum": SORGHUM_KENYA_LOCATIONS,
    }
    print(
        f"Starting batch processing. Storage Backend: {app_config.STORAGE_BACKEND}, Target Bucket: {target_bucket_name}, Base Prefix: {base_s3_prefix}"
    )

    for crop_id, locations_map in locations_to_process_config.items():
        for location_id, (lat, lon) in locations_map.items():
            print(
                f"Processing: Crop='{crop_id}', Location='{location_id}', Coords=({lat}, {lon})"
            )
            try:
                print(f"  1. Fetching weather data for {location_id}...")
                df_raw = fetch_weather_data(lat, lon, location_id)
                df_raw["crop_id"] = crop_id  # Add crop_id for validation and saving.

                print(f"  2. Validating weather data for {location_id}...")
                df_validated = validate_weather_data(df_raw.copy())

                print(
                    f"  3. Saving data for {location_id} to {app_config.STORAGE_BACKEND} storage..."
                )
                save_partitioned_parquet_s3(
                    df_validated, bucket=target_bucket_name, base_prefix=base_s3_prefix
                )
                print(f"  Data for {crop_id} - {location_id} saved successfully.")
            except Exception as e:
                print(f"  ERROR processing {crop_id} - {location_id}: {e}")

    print("Batch processing finished.")
# Out:
# Starting batch processing. Storage Backend: minio, Target Bucket: gdd-raw-weather-data, Base Prefix: bronze
# Processing: Crop='maize', Location='Belagavi', Coords=(15.85, 74.5)
#   1. Fetching weather data for Belagavi...
#   2. Validating weather data for Belagavi...
#   3. Saving data for Belagavi to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Belagavi/data_2025-05-24.parquet
#   Data for maize - Belagavi saved successfully.
# Processing: Crop='maize', Location='Chhindwara', Coords=(22.06, 78.94)
#   1. Fetching weather data for Chhindwara...
#   2. Validating weather data for Chhindwara...
#   3. Saving data for Chhindwara to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Chhindwara/data_2025-05-24.parquet
#   Data for maize - Chhindwara saved successfully.
# Processing: Crop='maize', Location='Jalgaon', Coords=(21.01, 75.56)
#   1. Fetching weather data for Jalgaon...
#   2. Validating weather data for Jalgaon...
#   3. Saving data for Jalgaon to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Jalgaon/data_2025-05-24.parquet
#   Data for maize - Jalgaon saved successfully.
# Processing: Crop='maize', Location='Perambalur', Coords=(11.23, 78.88)
#   1. Fetching weather data for Perambalur...
#   2. Validating weather data for Perambalur...
#   3. Saving data for Perambalur to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Perambalur/data_2025-05-24.parquet
#   Data for maize - Perambalur saved successfully.
# Processing: Crop='maize', Location='Katihar', Coords=(25.54, 87.58)
#   1. Fetching weather data for Katihar...
#   2. Validating weather data for Katihar...
#   3. Saving data for Katihar to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=maize/location_id=Katihar/data_2025-05-24.parquet
#   Data for maize - Katihar saved successfully.
# Processing: Crop='sorghum', Location='Kitui', Coords=(-1.38, 38.01)
#   1. Fetching weather data for Kitui...
#   2. Validating weather data for Kitui...
#   3. Saving data for Kitui to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Kitui/data_2025-05-24.parquet
#   Data for sorghum - Kitui saved successfully.
# Processing: Crop='sorghum', Location='Machakos', Coords=(-1.52, 37.27)
#   1. Fetching weather data for Machakos...
#   2. Validating weather data for Machakos...
#   3. Saving data for Machakos to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Machakos/data_2025-05-24.parquet
#   Data for sorghum - Machakos saved successfully.
# Processing: Crop='sorghum', Location='Makueni', Coords=(-2.24, 37.96)
#   1. Fetching weather data for Makueni...
#   2. Validating weather data for Makueni...
#   3. Saving data for Makueni to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Makueni/data_2025-05-24.parquet
#   Data for sorghum - Makueni saved successfully.
# Processing: Crop='sorghum', Location='Tharaka_Nithi', Coords=(-0.3, 37.93)
#   1. Fetching weather data for Tharaka_Nithi...
#   2. Validating weather data for Tharaka_Nithi...
#   3. Saving data for Tharaka_Nithi to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Tharaka_Nithi/data_2025-05-24.parquet
#   Data for sorghum - Tharaka_Nithi saved successfully.
# Processing: Crop='sorghum', Location='Siaya', Coords=(0.06, 34.29)
#   1. Fetching weather data for Siaya...
#   2. Validating weather data for Siaya...
#   3. Saving data for Siaya to minio storage...
# Saved data to s3://gdd-raw-weather-data/bronze/year=2025/month=05/crop_id=sorghum/location_id=Siaya/data_2025-05-24.parquet
#   Data for sorghum - Siaya saved successfully.
# Batch processing finished.
